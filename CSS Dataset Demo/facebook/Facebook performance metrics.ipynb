# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("dataset_Facebook.csv")

data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# Summary statistics for numeric columns
numeric_cols = ['Page total likes', 'Post Month', 'Post Weekday', 'Post Hour',
                'Lifetime Post Total Reach', 'Lifetime Post Total Impressions', 'Lifetime Engaged Users']
print(data[numeric_cols].describe())
# Out:
#        Page total likes  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    7.038000      4.150000    7.840000
# std        16272.813214    3.307936      2.030701    4.368589
# min        81370.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    7.000000      4.000000    9.000000
# 75%       136393.000000   10.000000      6.000000   11.000000
# max       139441.000000   12.000000      7.000000   23.000000
#
#        Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count                  500.00000                     5.000000e+02
# mean                 13903.36000                     2.958595e+04
# std                  22740.78789                     7.680325e+04
# min                    238.00000                     5.700000e+02
# 25%                   3315.00000                     5.694750e+03
# ...

# %%
# Distribution of post types
post_type_counts = data['Type'].value_counts()
plt.bar(post_type_counts.index, post_type_counts.values)
plt.xlabel('Post Type')
plt.ylabel('Count')
plt.title('Distribution of Post Types')
plt.show()

# %%
# Average reach for each post type
avg_reach_by_type = data.groupby('Type')['Lifetime Post Total Reach'].mean()
avg_reach_by_type.plot(kind='bar')
plt.ylabel('Average Reach')
plt.title('Average Reach by Post Type')
plt.show()

# %%
# Heatmap of correlations between numeric variables
correlation_matrix = data[numeric_cols].corr()
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(numeric_cols)), numeric_cols, rotation=45)
plt.yticks(range(len(numeric_cols)), numeric_cols)
plt.title('Correlation Heatmap')
plt.show()

# %%
https://www.kaggle.com/datasets/masoodanzar/facebook-metrics/data
    Exploratory Data Analysis of Facebook Performance Metrics
